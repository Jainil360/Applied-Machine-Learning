# %% [markdown]
# # NN

# %% [markdown]
# <p> <b>STEP 1 : </b> Importing Packages </p>

# %%
from sklearn.neural_network import MLPClassifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics 
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.datasets import load_iris

# %% [markdown]
# <p><b>STEP 2 : </b> Loading IRIS Dataset and Spliting the data</p>

# %%
FEATURE_NAMES = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']

iris = load_iris()
X = pd.DataFrame(iris.data, columns = FEATURE_NAMES)
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2 ,random_state=1)

# %% [markdown]
# <p><b>STEP 3 : </b> Creating the model and train the model</p>

# %% [markdown]
# activation : {'identity', 'logistic', 'tanh', 'relu'}, default='relu'
#     Activation function for the hidden layer.
#
#     - 'identity', no-op activation, useful to implement linear bottleneck,
#       returns f(x) = x
#
#     - 'logistic', the logistic sigmoid function,
#       returns f(x) = 1 / (1 + exp(-x)).
#
#     - 'tanh', the hyperbolic tan function,
#       returns f(x) = tanh(x).
#
#     - 'relu', the rectified linear unit function,
#       returns f(x) = max(0, x)

# %% [markdown]
# ### 1. Activation Function = relu

# %%
mlp = MLPClassifier(hidden_layer_sizes=(20,20),max_iter=1500)
mlp.fit(X_train,y_train)
predictions = mlp.predict(X_test)

print("Accuracy:",(metrics.accuracy_score(y_test, predictions))*100,'%')
# Out:
# Accuracy: 100.0 %

# %% [markdown]
# ### 2. Activation Function = logistic

# %%
mlp = MLPClassifier(hidden_layer_sizes=(20,20),max_iter=1500 ,activation='logistic')
mlp.fit(X_train,y_train)
predictions = mlp.predict(X_test)

print("Accuracy:",(metrics.accuracy_score(y_test, predictions))*100,'%')
# Out:
# Accuracy: 100.0 %

# %% [markdown]
# ### 3. Activation Function = tanh

# %%
mlp = MLPClassifier(hidden_layer_sizes=(20,20),max_iter=1500 ,activation='tanh')
mlp.fit(X_train,y_train)
predictions = mlp.predict(X_test)

print("Accuracy:",(metrics.accuracy_score(y_test, predictions))*100,'%')
# Out:
# Accuracy: 100.0 %

# %% [markdown]
# ### 4. Activation Function = identity

# %%
mlp = MLPClassifier(hidden_layer_sizes=(20,20),max_iter=1500 ,activation='identity')
mlp.fit(X_train,y_train)
predictions = mlp.predict(X_test)

print("Accuracy:",(metrics.accuracy_score(y_test, predictions))*100,'%')
# Out:
# Accuracy: 100.0 %

# %% [markdown]
# # Keras

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn import datasets, metrics
import pandas as pd
#w = pd.read_csv('E:/Iris.csv')
# print (w)
# X,y=datasets.load_iris(return_X_y=True)

FEATURE_NAMES = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']

iris = load_iris()


df1 = pd.DataFrame(iris.data, columns = FEATURE_NAMES)
df2 = pd.DataFrame(iris.target, columns = ['Target'])
df = pd.concat([df1,df2],axis='columns')

iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)
names = iris['target_names']
feature_names = iris['feature_names']

print(df)



# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
Y = encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y,test_size=0.2 ,random_state=1)
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width  Target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
model = Sequential()



model.add(Dense(units=4, input_shape=(4,),kernel_initializer = 'he_normal',activation = 'relu'))
# Hidden layer
model.add(Dense(units=7,  kernel_initializer='he_normal', activation='relu'))
# Output
model.add(Dense(units=3,  kernel_initializer='he_normal',activation='sigmoid'))
# Adam optimizer with learning rate of 0.001
# optimizer = Adam(lr=0.001)
model.compile(optimizer = 'adam', loss='binary_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())


model.fit(X_train, y_train,verbose=2, batch_size=5, epochs=200)



results = model.evaluate(X_test, y_test)
# Out:
# Neural Network Model Summary:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_68 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_69 (Dense)             (None, 7)                 35
# _________________________________________________________________
# dense_70 (Dense)             (None, 3)                 24
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 24/24 - 1s - loss: 0.7748 - accuracy: 0.1417
# Epoch 2/200
# 24/24 - 0s - loss: 0.6966 - accuracy: 0.1417
# Epoch 3/200
# 24/24 - 0s - loss: 0.6408 - accuracy: 0.3500
# Epoch 4/200
# 24/24 - 0s - loss: 0.6026 - accuracy: 0.5833
# Epoch 5/200
# 24/24 - 0s - loss: 0.5711 - accuracy: 0.6333
# Epoch 6/200
# 24/24 - 0s - loss: 0.5476 - accuracy: 0.6833
# Epoch 7/200
# 24/24 - 0s - loss: 0.5272 - accuracy: 0.6833
# Epoch 8/200
# 24/24 - 0s - loss: 0.5111 - accuracy: 0.6833
# Epoch 9/200
# 24/24 - 0s - loss: 0.4973 - accuracy: 0.6833
# Epoch 10/200
# 24/24 - 0s - loss: 0.4852 - accuracy: 0.6833
# Epoch 11/200
# 24/24 - 0s - loss: 0.4748 - accuracy: 0.6833
# Epoch 12/200
# 24/24 - 0s - loss: 0.4652 - accuracy: 0.6833
# Epoch 13/200
# 24/24 - 0s - loss: 0.4563 - accuracy: 0.6833
# Epoch 14/200
# 24/24 - 0s - loss: 0.4479 - accuracy: 0.6917
# Epoch 15/200
# 24/24 - 0s - loss: 0.4400 - accuracy: 0.6917
# Epoch 16/200
# 24/24 - 0s - loss: 0.4327 - accuracy: 0.6917
# Epoch 17/200
# 24/24 - 0s - loss: 0.4258 - accuracy: 0.6917
# Epoch 18/200
# 24/24 - 0s - loss: 0.4193 - accuracy: 0.6917
# Epoch 19/200
# 24/24 - 0s - loss: 0.4132 - accuracy: 0.7000
# Epoch 20/200
# 24/24 - 0s - loss: 0.4069 - accuracy: 0.7000
# Epoch 21/200
# 24/24 - 0s - loss: 0.4000 - accuracy: 0.7000
# Epoch 22/200
# 24/24 - 0s - loss: 0.3921 - accuracy: 0.7000
# Epoch 23/200
# 24/24 - 0s - loss: 0.3842 - accuracy: 0.7000
# Epoch 24/200
# 24/24 - 0s - loss: 0.3763 - accuracy: 0.6917
# Epoch 25/200
# 24/24 - 0s - loss: 0.3690 - accuracy: 0.6917
# Epoch 26/200
# 24/24 - 0s - loss: 0.3615 - accuracy: 0.6917
# Epoch 27/200
# 24/24 - 0s - loss: 0.3548 - accuracy: 0.6917
# Epoch 28/200
# 24/24 - 0s - loss: 0.3479 - accuracy: 0.6917
# Epoch 29/200
# 24/24 - 0s - loss: 0.3412 - accuracy: 0.7083
# Epoch 30/200
# 24/24 - 0s - loss: 0.3354 - accuracy: 0.7000
# Epoch 31/200
# 24/24 - 0s - loss: 0.3291 - accuracy: 0.7083
# Epoch 32/200
# 24/24 - 0s - loss: 0.3232 - accuracy: 0.7083
# Epoch 33/200
# 24/24 - 0s - loss: 0.3179 - accuracy: 0.7833
# Epoch 34/200
# 24/24 - 0s - loss: 0.3123 - accuracy: 0.8250
# Epoch 35/200
# 24/24 - 0s - loss: 0.3065 - accuracy: 0.8417
# Epoch 36/200
# 24/24 - 0s - loss: 0.3011 - accuracy: 0.8500
# Epoch 37/200
# 24/24 - 0s - loss: 0.2958 - accuracy: 0.8500
# Epoch 38/200
# 24/24 - 0s - loss: 0.2911 - accuracy: 0.8583
# Epoch 39/200
# 24/24 - 0s - loss: 0.2860 - accuracy: 0.8583
# Epoch 40/200
# 24/24 - 0s - loss: 0.2815 - accuracy: 0.8667
# Epoch 41/200
# 24/24 - 0s - loss: 0.2768 - accuracy: 0.8750
# Epoch 42/200
# 24/24 - 0s - loss: 0.2725 - accuracy: 0.8833
# Epoch 43/200
# 24/24 - 0s - loss: 0.2679 - accuracy: 0.8833
# Epoch 44/200
# 24/24 - 0s - loss: 0.2634 - accuracy: 0.8917
# Epoch 45/200
# 24/24 - 0s - loss: 0.2589 - accuracy: 0.9000
# Epoch 46/200
# 24/24 - 0s - loss: 0.2544 - accuracy: 0.9000
# Epoch 47/200
# 24/24 - 0s - loss: 0.2500 - accuracy: 0.9000
# Epoch 48/200
# 24/24 - 0s - loss: 0.2454 - accuracy: 0.9000
# Epoch 49/200
# 24/24 - 0s - loss: 0.2411 - accuracy: 0.9000
# Epoch 50/200
# 24/24 - 0s - loss: 0.2364 - accuracy: 0.9000
# Epoch 51/200
# 24/24 - 0s - loss: 0.2322 - accuracy: 0.9000
# Epoch 52/200
# 24/24 - 0s - loss: 0.2273 - accuracy: 0.9000
# Epoch 53/200
# 24/24 - 0s - loss: 0.2224 - accuracy: 0.9083
# Epoch 54/200
# 24/24 - 0s - loss: 0.2175 - accuracy: 0.9083
# Epoch 55/200
# 24/24 - 0s - loss: 0.2131 - accuracy: 0.9083
# Epoch 56/200
# 24/24 - 0s - loss: 0.2082 - accuracy: 0.9000
# Epoch 57/200
# 24/24 - 0s - loss: 0.2025 - accuracy: 0.9083
# Epoch 58/200
# 24/24 - 0s - loss: 0.1973 - accuracy: 0.9083
# Epoch 59/200
# 24/24 - 0s - loss: 0.1927 - accuracy: 0.9083
# Epoch 60/200
# 24/24 - 0s - loss: 0.1868 - accuracy: 0.9083
# Epoch 61/200
# 24/24 - 0s - loss: 0.1819 - accuracy: 0.9083
# Epoch 62/200
# 24/24 - 0s - loss: 0.1771 - accuracy: 0.9167
# Epoch 63/200
# 24/24 - 0s - loss: 0.1728 - accuracy: 0.9167
# Epoch 64/200
# 24/24 - 0s - loss: 0.1680 - accuracy: 0.9167
# Epoch 65/200
# 24/24 - 0s - loss: 0.1630 - accuracy: 0.9250
# Epoch 66/200
# 24/24 - 0s - loss: 0.1579 - accuracy: 0.9250
# Epoch 67/200
# 24/24 - 0s - loss: 0.1538 - accuracy: 0.9333
# Epoch 68/200
# 24/24 - 0s - loss: 0.1492 - accuracy: 0.9333
# Epoch 69/200
# 24/24 - 0s - loss: 0.1453 - accuracy: 0.9333
# Epoch 70/200
# 24/24 - 0s - loss: 0.1416 - accuracy: 0.9333
# Epoch 71/200
# 24/24 - 0s - loss: 0.1378 - accuracy: 0.9333
# Epoch 72/200
# 24/24 - 0s - loss: 0.1345 - accuracy: 0.9333
# Epoch 73/200
# 24/24 - 0s - loss: 0.1311 - accuracy: 0.9333
# Epoch 74/200
# 24/24 - 0s - loss: 0.1285 - accuracy: 0.9500
# Epoch 75/200
# 24/24 - 0s - loss: 0.1251 - accuracy: 0.9500
# Epoch 76/200
# 24/24 - 0s - loss: 0.1220 - accuracy: 0.9417
# Epoch 77/200
# 24/24 - 0s - loss: 0.1193 - accuracy: 0.9417
# Epoch 78/200
# 24/24 - 0s - loss: 0.1177 - accuracy: 0.9500
# Epoch 79/200
# 24/24 - 0s - loss: 0.1155 - accuracy: 0.9500
# Epoch 80/200
# 24/24 - 0s - loss: 0.1116 - accuracy: 0.9500
# Epoch 81/200
# 24/24 - 0s - loss: 0.1102 - accuracy: 0.9500
# Epoch 82/200
# 24/24 - 0s - loss: 0.1074 - accuracy: 0.9500
# Epoch 83/200
# 24/24 - 0s - loss: 0.1050 - accuracy: 0.9500
# Epoch 84/200
# 24/24 - 0s - loss: 0.1026 - accuracy: 0.9500
# Epoch 85/200
# 24/24 - 0s - loss: 0.1006 - accuracy: 0.9500
# Epoch 86/200
# 24/24 - 0s - loss: 0.0985 - accuracy: 0.9500
# Epoch 87/200
# 24/24 - 0s - loss: 0.0950 - accuracy: 0.9500
# Epoch 88/200
# 24/24 - 0s - loss: 0.0926 - accuracy: 0.9500
# Epoch 89/200
# 24/24 - 0s - loss: 0.0914 - accuracy: 0.9500
# Epoch 90/200
# 24/24 - 0s - loss: 0.0879 - accuracy: 0.9500
# Epoch 91/200
# 24/24 - 0s - loss: 0.0859 - accuracy: 0.9500
# Epoch 92/200
# 24/24 - 0s - loss: 0.0842 - accuracy: 0.9500
# Epoch 93/200
# 24/24 - 0s - loss: 0.0828 - accuracy: 0.9583
# Epoch 94/200
# 24/24 - 0s - loss: 0.0807 - accuracy: 0.9583
# Epoch 95/200
# 24/24 - 0s - loss: 0.0791 - accuracy: 0.9583
# Epoch 96/200
# 24/24 - 0s - loss: 0.0779 - accuracy: 0.9667
# Epoch 97/200
# 24/24 - 0s - loss: 0.0759 - accuracy: 0.9667
# Epoch 98/200
# 24/24 - 0s - loss: 0.0746 - accuracy: 0.9667
# Epoch 99/200
# 24/24 - 0s - loss: 0.0734 - accuracy: 0.9667
# Epoch 100/200
# 24/24 - 0s - loss: 0.0721 - accuracy: 0.9667
# Epoch 101/200
# 24/24 - 0s - loss: 0.0710 - accuracy: 0.9667
# Epoch 102/200
# 24/24 - 0s - loss: 0.0702 - accuracy: 0.9667
# Epoch 103/200
# 24/24 - 0s - loss: 0.0693 - accuracy: 0.9667
# Epoch 104/200
# 24/24 - 0s - loss: 0.0679 - accuracy: 0.9667
# Epoch 105/200
# 24/24 - 0s - loss: 0.0672 - accuracy: 0.9667
# Epoch 106/200
# 24/24 - 0s - loss: 0.0664 - accuracy: 0.9667
# Epoch 107/200
# 24/24 - 0s - loss: 0.0653 - accuracy: 0.9667
# Epoch 108/200
# 24/24 - 0s - loss: 0.0652 - accuracy: 0.9667
# Epoch 109/200
# 24/24 - 0s - loss: 0.0639 - accuracy: 0.9667
# Epoch 110/200
# 24/24 - 0s - loss: 0.0637 - accuracy: 0.9750
# Epoch 111/200
# 24/24 - 0s - loss: 0.0624 - accuracy: 0.9750
# Epoch 112/200
# 24/24 - 0s - loss: 0.0620 - accuracy: 0.9667
# Epoch 113/200
# 24/24 - 0s - loss: 0.0609 - accuracy: 0.9750
# Epoch 114/200
# 24/24 - 0s - loss: 0.0606 - accuracy: 0.9750
# Epoch 115/200
# 24/24 - 0s - loss: 0.0603 - accuracy: 0.9750
# Epoch 116/200
# 24/24 - 0s - loss: 0.0593 - accuracy: 0.9750
# Epoch 117/200
# 24/24 - 0s - loss: 0.0591 - accuracy: 0.9750
# Epoch 118/200
# 24/24 - 0s - loss: 0.0582 - accuracy: 0.9750
# Epoch 119/200
# 24/24 - 0s - loss: 0.0589 - accuracy: 0.9750
# Epoch 120/200
# 24/24 - 0s - loss: 0.0570 - accuracy: 0.9750
# Epoch 121/200
# 24/24 - 0s - loss: 0.0585 - accuracy: 0.9750
# Epoch 122/200
# 24/24 - 0s - loss: 0.0561 - accuracy: 0.9750
# Epoch 123/200
# 24/24 - 0s - loss: 0.0559 - accuracy: 0.9750
# Epoch 124/200
# 24/24 - 0s - loss: 0.0558 - accuracy: 0.9750
# Epoch 125/200
# 24/24 - 0s - loss: 0.0552 - accuracy: 0.9750
# Epoch 126/200
# 24/24 - 0s - loss: 0.0548 - accuracy: 0.9750
# Epoch 127/200
# 24/24 - 0s - loss: 0.0542 - accuracy: 0.9750
# Epoch 128/200
# 24/24 - 0s - loss: 0.0543 - accuracy: 0.9750
# Epoch 129/200
# 24/24 - 0s - loss: 0.0535 - accuracy: 0.9750
# Epoch 130/200
# 24/24 - 0s - loss: 0.0530 - accuracy: 0.9750
# Epoch 131/200
# 24/24 - 0s - loss: 0.0528 - accuracy: 0.9750
# Epoch 132/200
# 24/24 - 0s - loss: 0.0525 - accuracy: 0.9750
# Epoch 133/200
# 24/24 - 0s - loss: 0.0524 - accuracy: 0.9750
# Epoch 134/200
# 24/24 - 0s - loss: 0.0519 - accuracy: 0.9750
# Epoch 135/200
# 24/24 - 0s - loss: 0.0514 - accuracy: 0.9750
# Epoch 136/200
# 24/24 - 0s - loss: 0.0514 - accuracy: 0.9750
# Epoch 137/200
# 24/24 - 0s - loss: 0.0511 - accuracy: 0.9750
# Epoch 138/200
# 24/24 - 0s - loss: 0.0509 - accuracy: 0.9750
# Epoch 139/200
# 24/24 - 0s - loss: 0.0505 - accuracy: 0.9750
# Epoch 140/200
# 24/24 - 0s - loss: 0.0512 - accuracy: 0.9750
# Epoch 141/200
# 24/24 - 0s - loss: 0.0499 - accuracy: 0.9750
# Epoch 142/200
# 24/24 - 0s - loss: 0.0496 - accuracy: 0.9750
# Epoch 143/200
# 24/24 - 0s - loss: 0.0494 - accuracy: 0.9750
# Epoch 144/200
# 24/24 - 0s - loss: 0.0489 - accuracy: 0.9750
# Epoch 145/200
# 24/24 - 0s - loss: 0.0488 - accuracy: 0.9750
# Epoch 146/200
# 24/24 - 0s - loss: 0.0485 - accuracy: 0.9750
# Epoch 147/200
# 24/24 - 0s - loss: 0.0481 - accuracy: 0.9750
# Epoch 148/200
# 24/24 - 0s - loss: 0.0480 - accuracy: 0.9750
# Epoch 149/200
# 24/24 - 0s - loss: 0.0478 - accuracy: 0.9750
# Epoch 150/200
# 24/24 - 0s - loss: 0.0474 - accuracy: 0.9750
# Epoch 151/200
# 24/24 - 0s - loss: 0.0482 - accuracy: 0.9750
# Epoch 152/200
# 24/24 - 0s - loss: 0.0478 - accuracy: 0.9750
# Epoch 153/200
# 24/24 - 0s - loss: 0.0468 - accuracy: 0.9750
# Epoch 154/200
# 24/24 - 0s - loss: 0.0475 - accuracy: 0.9750
# Epoch 155/200
# 24/24 - 0s - loss: 0.0465 - accuracy: 0.9750
# Epoch 156/200
# 24/24 - 0s - loss: 0.0468 - accuracy: 0.9750
# Epoch 157/200
# 24/24 - 0s - loss: 0.0466 - accuracy: 0.9750
# Epoch 158/200
# 24/24 - 0s - loss: 0.0463 - accuracy: 0.9750
# Epoch 159/200
# 24/24 - 0s - loss: 0.0457 - accuracy: 0.9750
# Epoch 160/200
# 24/24 - 0s - loss: 0.0456 - accuracy: 0.9750
# Epoch 161/200
# 24/24 - 0s - loss: 0.0455 - accuracy: 0.9750
# Epoch 162/200
# 24/24 - 0s - loss: 0.0461 - accuracy: 0.9750
# Epoch 163/200
# 24/24 - 0s - loss: 0.0453 - accuracy: 0.9750
# Epoch 164/200
# 24/24 - 0s - loss: 0.0452 - accuracy: 0.9750
# Epoch 165/200
# 24/24 - 0s - loss: 0.0453 - accuracy: 0.9750
# Epoch 166/200
# 24/24 - 0s - loss: 0.0448 - accuracy: 0.9750
# Epoch 167/200
# 24/24 - 0s - loss: 0.0444 - accuracy: 0.9750
# Epoch 168/200
# 24/24 - 0s - loss: 0.0443 - accuracy: 0.9750
# Epoch 169/200
# 24/24 - 0s - loss: 0.0453 - accuracy: 0.9750
# Epoch 170/200
# 24/24 - 0s - loss: 0.0447 - accuracy: 0.9750
# Epoch 171/200
# 24/24 - 0s - loss: 0.0444 - accuracy: 0.9750
# Epoch 172/200
# 24/24 - 0s - loss: 0.0439 - accuracy: 0.9750
# Epoch 173/200
# 24/24 - 0s - loss: 0.0440 - accuracy: 0.9750
# Epoch 174/200
# 24/24 - 0s - loss: 0.0437 - accuracy: 0.9750
# Epoch 175/200
# 24/24 - 0s - loss: 0.0433 - accuracy: 0.9750
# Epoch 176/200
# 24/24 - 0s - loss: 0.0436 - accuracy: 0.9750
# Epoch 177/200
# 24/24 - 0s - loss: 0.0435 - accuracy: 0.9750
# Epoch 178/200
# 24/24 - 0s - loss: 0.0433 - accuracy: 0.9750
# Epoch 179/200
# 24/24 - 0s - loss: 0.0425 - accuracy: 0.9750
# Epoch 180/200
# 24/24 - 0s - loss: 0.0433 - accuracy: 0.9750
# Epoch 181/200
# 24/24 - 0s - loss: 0.0430 - accuracy: 0.9750
# Epoch 182/200
# 24/24 - 0s - loss: 0.0425 - accuracy: 0.9750
# Epoch 183/200
# 24/24 - 0s - loss: 0.0428 - accuracy: 0.9750
# Epoch 184/200
# 24/24 - 0s - loss: 0.0425 - accuracy: 0.9750
# Epoch 185/200
# 24/24 - 0s - loss: 0.0421 - accuracy: 0.9750
# Epoch 186/200
# 24/24 - 0s - loss: 0.0423 - accuracy: 0.9750
# Epoch 187/200
# 24/24 - 0s - loss: 0.0416 - accuracy: 0.9750
# Epoch 188/200
# 24/24 - 0s - loss: 0.0428 - accuracy: 0.9750
# Epoch 189/200
# 24/24 - 0s - loss: 0.0414 - accuracy: 0.9750
# Epoch 190/200
# 24/24 - 0s - loss: 0.0412 - accuracy: 0.9750
# Epoch 191/200
# 24/24 - 0s - loss: 0.0417 - accuracy: 0.9750
# Epoch 192/200
# 24/24 - 0s - loss: 0.0408 - accuracy: 0.9750
# Epoch 193/200
# 24/24 - 0s - loss: 0.0410 - accuracy: 0.9750
# Epoch 194/200
# 24/24 - 0s - loss: 0.0411 - accuracy: 0.9750
# Epoch 195/200
# 24/24 - 0s - loss: 0.0409 - accuracy: 0.9750
# Epoch 196/200
# 24/24 - 0s - loss: 0.0408 - accuracy: 0.9750
# Epoch 197/200
# 24/24 - 0s - loss: 0.0410 - accuracy: 0.9750
# Epoch 198/200
# 24/24 - 0s - loss: 0.0410 - accuracy: 0.9750
# Epoch 199/200
# 24/24 - 0s - loss: 0.0403 - accuracy: 0.9750
# Epoch 200/200
# 24/24 - 0s - loss: 0.0412 - accuracy: 0.9750
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x0000021A65257A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0389 - accuracy: 0.9667

# %%
y_pred = (model.predict(X_test) > 0.5)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred, normalize=True))
print(metrics.classification_report(y_test, y_pred))
# print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021A652579D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Accuracy: 0.9666666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.92      0.96        13
#            2       0.86      1.00      0.92         6
#
#    micro avg       0.97      0.97      0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30
#  samples avg       0.97      0.97      0.97        30
